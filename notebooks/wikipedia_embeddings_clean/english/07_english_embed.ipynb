# %% [markdown]
# # Do the embedding and upsert to pinecone

# %%
import sys
sys.path.append("../")

from importlib import reload
import wikipedia_embedder
reload(wikipedia_embedder)

from wikipedia_embedder import WikiEmbedder


input_parquet_path = "df_english_filtered_articles.cache.parquet"
checkpoint_path = "df_checkpoint.parquet"
pinecone_index_name = "english-wiki"

# batch size controls how many we upsert to pinecone at a time
# and also how many are embedded at a time.
# something like 50 is a good number.
batch_size = 50
embedding_model = "multilingual-e5-large"


wiki_embedder = WikiEmbedder(
    input_parquet_path,
    checkpoint_path,
    pinecone_index_name,
    batch_size=batch_size,
    embedding_model=embedding_model,
)

wiki_embedder.print_init_info()
# Out:
# 2024-12-08 11:08:13,010 - INFO - Discovering subpackages in _NamespacePath(['/Users/einar/git/hafsteinn/together_rag/venv/lib/python3.10/site-packages/pinecone_plugins'])
# 2024-12-08 11:08:13,012 - INFO - Looking for plugins in pinecone_plugins.inference
# 2024-12-08 11:08:13,012 - INFO - Installing plugin inference into Pinecone
# 2024-12-08 11:08:15,504 - INFO - Found 49680 fully processed articles
# 2024-12-08 11:08:15,505 - INFO - Processing remaining 320 articles (including partially processed)
# ====================================================================================================
# Original number of articles: 50000
# Total number of chunks: 753048
# Embedding model: multilingual-e5-large
# Batch size: 50
# Checkpoint path: df_checkpoint.parquet
# N rows in checkpoint: 752728
# N unique articles in checkpoint: 49680
# N articles to process: 320
# n checkpoint + n top process (sanity check): 50000

# %%
"""
NOTE: takes around 8 hours to run for 50K articles of the english wikipedia.
"""

# controls how many articles are processed at a time
articles_per_batch = 10

wiki_embedder.process_articles(articles_per_batch=articles_per_batch)
# Out:
# 2024-12-08 11:08:19,723 - INFO - Processing articles 0 to 9
# 2024-12-08 11:08:19,724 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:20,487 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:21,116 - INFO - Completed processing batch. Total processed chunks: 752738
# 2024-12-08 11:08:21,116 - INFO - Processing articles 10 to 19
# 2024-12-08 11:08:21,117 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:21,662 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:22,040 - INFO - Completed processing batch. Total processed chunks: 752748
# 2024-12-08 11:08:22,040 - INFO - Processing articles 20 to 29
# 2024-12-08 11:08:22,040 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:22,520 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:22,827 - INFO - Completed processing batch. Total processed chunks: 752758
# 2024-12-08 11:08:22,828 - INFO - Processing articles 30 to 39
# 2024-12-08 11:08:22,828 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:23,325 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:23,500 - INFO - Completed processing batch. Total processed chunks: 752768
# 2024-12-08 11:08:23,500 - INFO - Processing articles 40 to 49
# 2024-12-08 11:08:23,501 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:24,023 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:24,215 - INFO - Completed processing batch. Total processed chunks: 752778
# 2024-12-08 11:08:24,215 - INFO - Processing articles 50 to 59
# 2024-12-08 11:08:24,216 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:24,738 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:24,917 - INFO - Completed processing batch. Total processed chunks: 752788
# 2024-12-08 11:08:24,917 - INFO - Processing articles 60 to 69
# 2024-12-08 11:08:24,918 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:25,430 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:25,610 - INFO - Completed processing batch. Total processed chunks: 752798
# 2024-12-08 11:08:25,611 - INFO - Processing articles 70 to 79
# 2024-12-08 11:08:25,611 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:26,146 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:26,328 - INFO - Completed processing batch. Total processed chunks: 752808
# 2024-12-08 11:08:26,329 - INFO - Processing articles 80 to 89
# 2024-12-08 11:08:26,329 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:26,953 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:27,144 - INFO - Completed processing batch. Total processed chunks: 752818
# 2024-12-08 11:08:27,144 - INFO - Processing articles 90 to 99
# 2024-12-08 11:08:27,144 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:27,670 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:27,833 - INFO - Completed processing batch. Total processed chunks: 752828
# 2024-12-08 11:08:27,834 - INFO - Processing articles 100 to 109
# 2024-12-08 11:08:27,834 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:28,470 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:28,636 - INFO - Completed processing batch. Total processed chunks: 752838
# 2024-12-08 11:08:28,636 - INFO - Processing articles 110 to 119
# 2024-12-08 11:08:28,637 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:29,152 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:29,344 - INFO - Completed processing batch. Total processed chunks: 752848
# 2024-12-08 11:08:29,345 - INFO - Processing articles 120 to 129
# 2024-12-08 11:08:29,345 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:29,874 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:30,027 - INFO - Completed processing batch. Total processed chunks: 752858
# 2024-12-08 11:08:30,027 - INFO - Processing articles 130 to 139
# 2024-12-08 11:08:30,028 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:30,534 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:30,715 - INFO - Completed processing batch. Total processed chunks: 752868
# 2024-12-08 11:08:30,716 - INFO - Processing articles 140 to 149
# 2024-12-08 11:08:30,716 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:31,181 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:31,379 - INFO - Completed processing batch. Total processed chunks: 752878
# 2024-12-08 11:08:31,380 - INFO - Processing articles 150 to 159
# 2024-12-08 11:08:31,380 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:31,902 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:32,088 - INFO - Completed processing batch. Total processed chunks: 752888
# 2024-12-08 11:08:32,088 - INFO - Processing articles 160 to 169
# 2024-12-08 11:08:32,088 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:32,580 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:32,752 - INFO - Completed processing batch. Total processed chunks: 752898
# 2024-12-08 11:08:32,753 - INFO - Processing articles 170 to 179
# 2024-12-08 11:08:32,753 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:33,256 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:33,666 - INFO - Completed processing batch. Total processed chunks: 752908
# 2024-12-08 11:08:33,666 - INFO - Processing articles 180 to 189
# 2024-12-08 11:08:33,666 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:34,198 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:34,400 - INFO - Completed processing batch. Total processed chunks: 752918
# 2024-12-08 11:08:34,401 - INFO - Processing articles 190 to 199
# 2024-12-08 11:08:34,401 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:34,970 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:35,137 - INFO - Completed processing batch. Total processed chunks: 752928
# 2024-12-08 11:08:35,137 - INFO - Processing articles 200 to 209
# 2024-12-08 11:08:35,138 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:35,605 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:35,763 - INFO - Completed processing batch. Total processed chunks: 752938
# 2024-12-08 11:08:35,764 - INFO - Processing articles 210 to 219
# 2024-12-08 11:08:35,764 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:36,274 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:36,456 - INFO - Completed processing batch. Total processed chunks: 752948
# 2024-12-08 11:08:36,456 - INFO - Processing articles 220 to 229
# 2024-12-08 11:08:36,457 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:36,955 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:37,130 - INFO - Completed processing batch. Total processed chunks: 752958
# 2024-12-08 11:08:37,130 - INFO - Processing articles 230 to 239
# 2024-12-08 11:08:37,131 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:37,637 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:37,811 - INFO - Completed processing batch. Total processed chunks: 752968
# 2024-12-08 11:08:37,812 - INFO - Processing articles 240 to 249
# 2024-12-08 11:08:37,812 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:38,350 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:38,550 - INFO - Completed processing batch. Total processed chunks: 752978
# 2024-12-08 11:08:38,550 - INFO - Processing articles 250 to 259
# 2024-12-08 11:08:38,551 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:39,064 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:39,230 - INFO - Completed processing batch. Total processed chunks: 752988
# 2024-12-08 11:08:39,231 - INFO - Processing articles 260 to 269
# 2024-12-08 11:08:39,231 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:39,756 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:39,932 - INFO - Completed processing batch. Total processed chunks: 752998
# 2024-12-08 11:08:39,932 - INFO - Processing articles 270 to 279
# 2024-12-08 11:08:39,933 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:40,459 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:40,618 - INFO - Completed processing batch. Total processed chunks: 753008
# 2024-12-08 11:08:40,618 - INFO - Processing articles 280 to 289
# 2024-12-08 11:08:40,619 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:41,158 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:41,337 - INFO - Completed processing batch. Total processed chunks: 753018
# 2024-12-08 11:08:41,337 - INFO - Processing articles 290 to 299
# 2024-12-08 11:08:41,338 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:41,954 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:42,124 - INFO - Completed processing batch. Total processed chunks: 753028
# 2024-12-08 11:08:42,130 - INFO - Processing articles 300 to 309
# 2024-12-08 11:08:42,131 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:42,631 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:42,872 - INFO - Completed processing batch. Total processed chunks: 753038
# 2024-12-08 11:08:42,873 - INFO - Processing articles 310 to 319
# 2024-12-08 11:08:42,873 - INFO - N chunks in batch: 10
# 2024-12-08 11:08:43,350 - INFO - Processed batch 1: Embeddings 0 to 49
# 2024-12-08 11:08:43,519 - INFO - Completed processing batch. Total processed chunks: 753048

# %% [markdown]
# # Inspect the checkpoint

# %%
"""
for ref from above:
Processing 50000 articles
Total number of chunks: 753048
Embedding model: multilingual-e5-large
Batch size: 50
Checkpoint path: df_checkpoint.parquet
N rows in checkpoint: 8710
N unique articles in checkpoint: 60
"""

import pandas as pd

df_checkpoint = pd.read_parquet(checkpoint_path)
print(len(df_checkpoint))
print(len(df_checkpoint["title_match"].unique()))
df_checkpoint.head(2)
# Out:
# 660872
# 28490
#   title_match  chunk_idx
# 0       2000s          0
# 1       2000s          1

# %%
done_perc_chunks = len(df_checkpoint) / wiki_embedder.df.n_chunks.sum()
done_perc_articles = len(df_checkpoint.title_match.unique()) / len(wiki_embedder.df.title_match.unique())
print(f"Done {done_perc_chunks:.2%} of chunks")
print(f"Done {done_perc_articles:.2%} of articles")
# Out:
# Done 87.76% of chunks
# Done 56.98% of articles
